# %%
from portfolio_test.forge_data import DataForge
from portfolio_test.portfolio_manager import PortfolioManager
from portfolio_test.portfolio_service import PortfolioStatisticsService
from portfolio_test.motor import CalculationMotor
import pandas as pd

# %%
pm = PortfolioManager()

# %% [markdown]
# Calculation Motor

# %%
data_forge = DataForge()

# %%
cm_temp = CalculationMotor("AAPL")

# %%
pm.get_portfolio_snapshot()

# %%
# if data exists
if "data" not in locals():
    data = data_forge.add_column_of_data(cm_temp.df["Adj Close"], column_name="Close (AAPL)")

# %%
pm.get_portfolio_value_history()

# %% [markdown]
# ### Build trade identifiers

# %%
close_column = "Close (AAPL)"
# do not shift here, we want to use the current day's EMA for the signal, as signal is day close, I think this is fair
data['EMA_20'] = data[close_column].ewm(span=20).mean().shift(0)
data['EMA_50'] = data[close_column].ewm(span=50).mean().shift(0)

data['Signal'] = 0
# Buy when 20 EMA > 50 EMA
data.loc[data['EMA_20'] > data['EMA_50'], 'Signal'] = 1
# Sell (or Cash) when 20 EMA < 50 EMA
data.loc[data['EMA_20'] < data['EMA_50'], 'Signal'] = 0

# %%
data

# %%
for date in data.index:
    print(f"- - - - - Date: {date.date()} - - - - -")
    buy_signal =  data.loc[date, 'Signal']
    buy_signal_ydy = data['Signal'].shift(1).loc[date]

    if buy_signal and not buy_signal_ydy:
        pm.record_transaction_percentage_buy_sell(
            tx_type="BUY",
            ticker="AAPL",
            pcnt_of_portfolio=1,
            data_one_date=data.loc[date]
        )
    # if price today is higher than yesterday, sell all shares
    elif not buy_signal and buy_signal_ydy:
        pm.record_transaction_percentage_buy_sell(
            tx_type="SELL",
            ticker="AAPL",
            pcnt_of_portfolio=1,
            data_one_date=data.loc[date]
        )

# %%
pm.get_portfolio_snapshot()

# %%
# Get benchmark data (S&P 500)
sp500 = CalculationMotor("^GSPC", start="2020-01-01")
benchmark_data = sp500.df["Adj Close"].copy()
benchmark_data.index = pd.to_datetime(benchmark_data.index).normalize()

ps = PortfolioStatisticsService(pm, benchmark_series=benchmark_data)

# Print comprehensive performance summary
ps.print_performance_summary()
