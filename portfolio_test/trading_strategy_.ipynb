# %%
from portfolio_test.forge_data import DataForge
from portfolio_test.portfolio_manager import PortfolioManager
from portfolio_test.portfolio_service import PortfolioStatisticsService
from portfolio_test.motor import CalculationMotor
import pandas as pd

# %%
pm = PortfolioManager()

# %% [markdown]
# Calculation Motor

# %%
data_forge = DataForge()

# %%
cm_temp = CalculationMotor("AAPL")

# %%
pm.get_portfolio_snapshot()

# %%
# if data exists
if "data" not in locals():
    data = data_forge.add_column_of_data(cm_temp.df["Adj Close"], column_name="Close (AAPL)")

# %%
pm.get_portfolio_value_history()

# %% [markdown]
# ### Build trade identifiers

# %%
close_column = "Close (AAPL)"
# do not shift here, we want to use the current day's EMA for the signal, as signal is day close, I think this is fair
data['EMA_20'] = data[close_column].ewm(span=20).mean().shift(0)
data['EMA_50'] = data[close_column].ewm(span=50).mean().shift(0)

data['Signal'] = 0
# Buy when 20 EMA > 50 EMA
data.loc[data['EMA_20'] > data['EMA_50'], 'Signal'] = 1
# Sell (or Cash) when 20 EMA < 50 EMA
data.loc[data['EMA_20'] < data['EMA_50'], 'Signal'] = 0

# %%
data

# %%
for date in data.index:
    print(f"- - - - - Date: {date.date()} - - - - -")
    buy_signal =  data.loc[date, 'Signal']
    buy_signal_ydy = data['Signal'].shift(1).loc[date]

    if buy_signal and not buy_signal_ydy:
        pm.record_transaction_percentage_buy_sell(
            tx_type="BUY",
            ticker="AAPL",
            pcnt_of_portfolio=1,
            data_one_date=data.loc[date]
        )
    # if price today is higher than yesterday, sell all shares
    elif not buy_signal and buy_signal_ydy:
        pm.record_transaction_percentage_buy_sell(
            tx_type="SELL",
            ticker="AAPL",
            pcnt_of_portfolio=1,
            data_one_date=data.loc[date]
        )

# %%
pm.get_portfolio_snapshot()

# %%
# Get benchmark data (S&P 500)
sp500 = CalculationMotor("^GSPC", start="2020-01-01")
benchmark_data = sp500.df["Adj Close"].copy()
benchmark_data.index = pd.to_datetime(benchmark_data.index).normalize()

print(f"Benchmark data fetched: {len(benchmark_data)} days of S&P 500 data")

# %%
starting_cash = pm.starting_cash
ps = PortfolioStatisticsService(pm, benchmark_series=benchmark_data)

# %%
# Print comprehensive performance summary
ps.print_performance_summary()

# %%
earnings = ps.get_total_valuation()
trading_gain = earnings / starting_cash
print(f"\nTotal portfolio value: {earnings:.2f} SEK")
print(f"Trading gain multiplier: {trading_gain:.3f}x")

# %%
# Compare to buy and hold AAPL
last_price = data.loc[data.index.max(), close_column]
first_price = data.loc[data.index.min(), close_column]
holding_gain = last_price / first_price

print(f"\n🎯 STRATEGY vs BUY & HOLD (AAPL):")
print(f"Strategy return: {(trading_gain - 1) * 100:.2f}%")
print(f"Buy & Hold return: {(holding_gain - 1) * 100:.2f}%")

if trading_gain > holding_gain:
    multiplier = (trading_gain - 1) / (holding_gain - 1) if (holding_gain - 1) != 0 else float('inf')
    print(f"✅ Strategy OUTPERFORMED by {multiplier:.2f}x")
else:
    multiplier = (holding_gain - 1) / (trading_gain - 1) if (trading_gain - 1) != 0 else float('inf')
    print(f"❌ Strategy UNDERPERFORMED by {multiplier:.2f}x")

# %%
# Get detailed Sharpe Ratio metrics
sharpe_portfolio = ps.get_sharpe_ratio()
sharpe_benchmark = ps.get_benchmark_sharpe_ratio()

print(f"\n📊 RISK-ADJUSTED RETURNS:")
print(f"Portfolio Sharpe Ratio: {sharpe_portfolio['sharpe_ratio']:.4f}")
print(f"  - Annualized Return: {sharpe_portfolio['annualized_return']*100:.2f}%")
print(f"  - Annualized Volatility: {sharpe_portfolio['annualized_volatility']*100:.2f}%")

print(f"\nBenchmark (S&P 500) Sharpe Ratio: {sharpe_benchmark['sharpe_ratio']:.4f}")
print(f"  - Annualized Return: {sharpe_benchmark['annualized_return']*100:.2f}%")
print(f"  - Annualized Volatility: {sharpe_benchmark['annualized_volatility']*100:.2f}%")

print(f"\nNote: S&P 500 historically has Sharpe ~0.5-0.7")
print(f"A ratio of 1.0+ means outperforming on a risk-adjusted basis")

# %%
# Get max drawdown comparison
drawdown_portfolio = ps.get_max_drawdown()
drawdown_benchmark = ps.get_benchmark_max_drawdown()

print(f"\n📉 MAXIMUM DRAWDOWN:")
print(f"Portfolio Max Drawdown: {drawdown_portfolio['max_drawdown']*100:.2f}%")
print(f"  - Occurred on: {drawdown_portfolio['max_drawdown_date']}")

print(f"\nBenchmark Max Drawdown: {drawdown_benchmark['max_drawdown']*100:.2f}%")
print(f"  - Occurred on: {drawdown_benchmark['max_drawdown_date']}")

if abs(drawdown_portfolio['max_drawdown']) < abs(drawdown_benchmark['max_drawdown']):
    print(f"✅ Your strategy had LESS downside risk")
else:
    print(f"❌ Your strategy had MORE downside risk")

# %%
# Win rate analysis
win_rate = ps.get_win_rate()
print(f"\n📈 TRADE ANALYSIS:")
print(f"Total Trades: {win_rate['total_trades']}")
print(f"Winning Trades: {win_rate['winning_trades']}")
print(f"Losing Trades: {win_rate['losing_trades']}")
print(f"Win Rate: {win_rate['win_rate']*100:.2f}%")

# %%
# Full benchmark comparison
comparison = ps.compare_to_benchmark()
print(f"\n🏆 FULL BENCHMARK COMPARISON:")
print(f"Portfolio Total Return: {comparison['portfolio_return']*100:.2f}%")
print(f"Benchmark Total Return: {comparison['benchmark_return']*100:.2f}%")
print(f"Excess Return: {comparison['excess_return']*100:.2f}%")
print(f"\nPortfolio Sharpe Ratio: {comparison['portfolio_sharpe']:.4f}")
print(f"Benchmark Sharpe Ratio: {comparison['benchmark_sharpe']:.4f}")
print(f"Sharpe Outperformance: {comparison['sharpe_outperformance']:.4f}")
